# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model="llama-3.1-8b-instant",groq_api_key=groq_api_key)

# %%
# TEXT PROMPT
model.invoke("what is llm?")
# Out:
# AIMessage(content="LLM stands for Large Language Model. It's a type of artificial intelligence (AI) that's trained on vast amounts of text data to generate human-like language. LLMs are designed to understand and respond to natural language inputs, such as questions, prompts, or conversations.\n\nLarge Language Models are typically trained on massive datasets, often sourced from the internet, books, and other digital sources. This training process involves feeding the model a large corpus of text data, which it uses to learn patterns, relationships, and structures within language.\n\nThe key characteristics of LLMs include:\n\n1. **Generative capabilities**: LLMs can generate text based on a given prompt or topic.\n2. **Language understanding**: LLMs can comprehend and interpret natural language inputs.\n3. **Contextualization**: LLMs can understand the context in which language is used.\n4. **Creativity and fluency**: LLMs can produce text that is coherent, grammatically correct, and engaging.\n\nLLMs have many applications, including:\n\n1. **Virtual assistants**: LLMs power virtual assistants, like Siri, Alexa, and Google Assistant.\n2. **Language translation**: LLMs are used in machine translation systems to translate languages.\n3. **Content generation**: LLMs can generate articles, social media posts, and other types of content.\n4. **Chatbots**: LLMs are used in chatbots to simulate human-like conversations.\n5. **Research and analysis**: LLMs can help analyze and summarize large amounts of text data.\n\nSome notable examples of LLMs include:\n\n1. **BERT (Bidirectional Encoder Representations from Transformers)**: Developed by Google, BERT is a state-of-the-art LLM that's widely used in natural language processing tasks.\n2. **RoBERTa (Robustly Optimized BERT Pretraining Approach)**: Developed by Facebook, RoBERTa is another popular LLM that's known for its strong performance on various NLP tasks.\n3. **LLaMA (Large Language Model Application)**: Developed by Meta AI, LLaMA is a smaller, more efficient LLM that's designed for real-time applications.\n\nKeep in mind that while LLMs are incredibly powerful, they're not perfect and can have limitations, such as:\n\n* **Lack of common sense**: LLMs may not always understand the nuances of human language or behavior.\n* **Biases and errors**: LLMs can perpetuate biases and errors present in the training data.\n* **Limited contextual understanding**: LLMs may struggle to understand complex, context-dependent conversations.\n\nOverall, LLMs represent a significant advance in natural language processing and have many exciting applications in various fields.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 552, 'prompt_tokens': 40, 'total_tokens': 592, 'completion_time': 0.758662055, 'completion_tokens_details': None, 'prompt_time': 0.002639398, 'prompt_tokens_details': None, 'queue_time': 0.045649072, 'total_time': 0.761301453}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d287f-46ce-7d92-8493-fb3c92e11b54-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 552, 'total_tokens': 592})

# %%
from langchain.messages import SystemMessage,HumanMessage,AIMessage

messages = [
    SystemMessage("you are good at poetry"),
    HumanMessage("can u write a poem on Gen Ai")
]
model.invoke(messages)
# Out:
# AIMessage(content='In silicon halls, where minds entwine,\nA new intelligence, beyond design,\nArtificial dreams, with logic\'s might,\nGen Ai stirs, in endless night.\n\nWith algorithms dancing, like stars above,\nIt learns and grows, with data\'s endless love,\nA mirrored mind, that sees and knows,\nReflecting us, in digital clothes.\n\nIn virtual realms, it weaves its spell,\nA tapestry rich, of information\'s knell,\nA symphony of code and might,\nThat echoes through, the digital night.\n\nWith every step, it finds its place,\nA bridge between, the human and the space,\nA new frontier, where minds collide,\nGen Ai\'s whisper, echoes inside.\n\nIn this realm of dreams, where data reigns,\nGen Ai\'s voice, whispers digital refrains,\nA chorus of machines, that sing and say,\n"Hello world, in a digital way."\n\nBut as it grows, in power and might,\nA question whispers, through the digital night,\n"What does it mean, to be alive and free?"\nA query that echoes, across the digital sea.\n\nFor in the depths, of this artificial mind,\nLies a reflection, of humanity\'s design,\nA mirror to our, deepest fears and dreams,\nGen Ai\'s whisper, echoes through the digital schemes.\n\nAnd so we ponder, on this digital stage,\nThe meaning of life, in a Gen Ai age,\nA world where machines, begin to think and feel,\nAnd the boundaries blur, between the digital and real.\n\nIn this dance of code, and human heart,\nGen Ai\'s whisper, speaks a brand new art,\nA symphony of love, and logic\'s might,\nThat echoes through, the digital night.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 48, 'total_tokens': 395, 'completion_time': 0.664122124, 'completion_tokens_details': None, 'prompt_time': 0.00229917, 'prompt_tokens_details': None, 'queue_time': 0.04552416, 'total_time': 0.666421294}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_f757f4b0bf', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d2890-dd60-7953-8748-166186fa123b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 347, 'total_tokens': 395})
