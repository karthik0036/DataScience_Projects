# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
repo_id = "meta-llama/Llama-4-Scout-17B-16E-Instruct"

llm_endpoint = HuggingFaceEndpoint(repo_id=repo_id,max_new_tokens=512,temperature=0.7,huggingfacehub_api_token=os.getenv("HF_TOKEN"))
chat_model = ChatHuggingFace(llm = llm_endpoint )

# %%
prompt = ChatPromptTemplate.from_template(
    """
    Question:{question}
    Answer:Lets think step by step.
    """
)

parser = StrOutputParser()

chain = prompt | chat_model | parser

# %%
chain.invoke({"question":"what is machine learning?"})
# Out:
# 'To understand what machine learning is, let\'s break it down step by step:\n\n1. **Understanding the Term "Machine Learning"**: The term itself suggests a combination of two key concepts: machines (or computers) and learning. Learning, in a general sense, refers to the process of acquiring new understanding, knowledge, behaviors, skills, values, or preferences.\n\n2. **Traditional Programming vs. Machine Learning**:\n   - **Traditional Programming**: In traditional computer programming, a programmer writes explicit instructions (code) for a computer to perform a specific task. The programmer provides the computer with a clear, step-by-step guide on how to solve a problem or complete a task. This approach works well for tasks that have a clear, well-defined set of rules.\n   - **Machine Learning**: Machine learning, on the other hand, enables computers to learn from data and improve their performance on a task without being explicitly programmed for that task. Instead of following pre-defined rules, machine learning algorithms use statistical techniques to allow computers to "learn" from data.\n\n3. **The Learning Process in Machine Learning**:\n   - The learning process in machine learning involves feeding data into an algorithm, which then uses this data to make predictions, classify objects, make decisions, or generate insights. \n   - The algorithm iteratively improves its performance on a task as it is exposed to more data. This improvement is based on the algorithm\'s ability to identify patterns or relationships within the data.\n\n4. **Types of Machine Learning**:\n   - **Supervised Learning**: The algorithm learns from labeled data, where the correct output is already known. It\'s like learning with a teacher providing answers.\n   - **Unsupervised Learning**: The algorithm learns from unlabeled data, identifying patterns or structures without prior knowledge of the correct output.\n   - **Reinforcement Learning**: The algorithm learns through trial and error, receiving feedback in the form of rewards or penalties for its actions.\n\n5. **Applications of Machine Learning**:\n   - Machine learning has a wide range of applications across various industries, including but not limited to:\n     - **Healthcare**: Predicting diseases based on patient data.\n     - **Finance**: Detecting fraudulent transactions.\n     - **E-commerce**: Recommending products to customers.\n     - **Autonomous Vehicles**: Enabling cars to drive themselves by interpreting sensory data.\n\n6. **Conclusion**: Machine learning represents a significant shift from traditional programming methods, enabling computers to perform complex tasks by learning from data rather than following explicit instructions. This capability has opened up new possibilities for automation, prediction, and decision-making'

# %%
chain.invoke({"question":"who won cricket worldcup 2012?"})
# Out:
# "To find out who won the Cricket World Cup in 2012, let's consider the facts:\n\n1. **Cricket World Cup Schedule**: The ICC Cricket World Cup is held every four years. The tournament before 2012 would have been in 2007, and the one after would have been in 2011.\n\n2. **2011 Cricket World Cup**: The 2011 ICC Cricket World Cup was held in India, Sri Lanka, and Bangladesh. India won this tournament by defeating Sri Lanka in the final.\n\n3. **2015 Cricket World Cup**: The next tournament after 2011 was held in 2015 in Australia and New Zealand, where Australia won.\n\nGiven this information, we can deduce that there wasn't a Cricket World Cup held in 2012. The tournaments are held every four years, making the sequence:\n\n- 2007 (West Indies)\n- 2011 (India)\n- 2015 (Australia)\n\nTherefore, there was no Cricket World Cup winner in 2012.\n\nHowever, there was a **T20 World Cup** in 2012. The 2012 ICC World Twenty20 was held in Sri Lanka. \n\n- **2012 ICC World Twenty20 Winner**: West Indies won this tournament by defeating Sri Lanka in the final.\n\nSo, depending on the specific tournament you're referring to, the answer could differ:\n\n- For the ICC Cricket World Cup, there wasn't one in 2012.\n- For the ICC World Twenty20, West Indies won in 2012."
