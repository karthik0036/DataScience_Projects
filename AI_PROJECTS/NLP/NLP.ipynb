# %%
corpus = """hello ,this is new comer to nlp. 
Natural language processing helps to tokenize the words. 
by doing coding so learning nlp!
"""

# %%
from nltk import sent_tokenize

# %%
print(sent_tokenize(corpus))
# Out:
# ['hello ,this is new comer to nlp.', 'Natural language processing helps to tokenize the words.', 'by doing coding so learning nlp!']

# %%
type(sent_tokenize(corpus))
# Out:
# list

# %%
docs = sent_tokenize(corpus)

for i in docs:
    print(i)
# Out:
# hello ,this is new comer to nlp.
# Natural language processing helps to tokenize the words.
# by doing coding so learning nlp!

# %%
## tokenize 
# paragraph/sentence => words

from nltk.tokenize import word_tokenize
# from nltk.tokenize import wordpunct_tokenize

# %%
for sentence in docs:
    print(word_tokenize(sentence))
# Out:
# ['hello', ',', 'this', 'is', 'new', 'comer', 'to', 'nlp', '.']
# ['Natural', 'language', 'processing', 'helps', 'to', 'tokenize', 'the', 'words', '.']
# ['by', 'doing', 'coding', 'so', 'learning', 'nlp', '!']

# %%
word_tokenize(corpus)
# Out:
# ['hello',
#  ',',
#  'this',
#  'is',
#  'new',
#  'comer',
#  'to',
#  'nlp',
#  '.',
#  'Natural',
#  'language',
#  'processing',
#  'helps',
#  'to',
#  'tokenize',
#  'the',
#  'words',
#  '.',
#  'by',
#  'doing',
#  'coding',
#  'so',
#  'learning',
#  'nlp',
#  '!']

# %%
# from nltk.tokenize import word_tokenize
# from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()

tokenizer.tokenize(corpus)
# Out:
# ['hello',
#  ',',
#  'this',
#  'is',
#  'new',
#  'comer',
#  'to',
#  'nlp.',
#  'Natural',
#  'language',
#  'processing',
#  'helps',
#  'to',
#  'tokenize',
#  'the',
#  'words.',
#  'by',
#  'doing',
#  'coding',
#  'so',
#  'learning',
#  'nlp',
#  '!']

# %%
## Stemming 
#eating,eaten,eat =>eat 
#going,goes,gonw => go [root word]

# %%
words = [
    "eat", "eating", "eaten", "eats",
    "play", "playing", "played", "plays",
    "run", "running", "ran", "runs",
    "walk", "walking", "walked", "walks"
]

# %%
from nltk.stem import PorterStemmer

stemming = PorterStemmer()

# %%
for word in words:
    print(word+"---->"+ stemming.stem(word))
# Out:
# eat---->eat
# eating---->eat
# eaten---->eaten
# eats---->eat
# play---->play
# playing---->play
# played---->play
# plays---->play
# run---->run
# running---->run
# ran---->ran
# runs---->run
# walk---->walk
# walking---->walk
# walked---->walk
# walks---->walk

# %%
words1 = [
    "connect", "connected", "connecting", "connection", "connections",
    "compute", "computer", "computing", "computation",
    "analyze", "analysis", "analyst", "analyzing",
    "predict", "prediction", "predictive", "predicting"
]

# %%
for word in words1:
    print(word+"---->"+ stemming.stem(word))
# Out:
# connect---->connect
# connected---->connect
# connecting---->connect
# connection---->connect
# connections---->connect
# compute---->comput
# computer---->comput
# computing---->comput
# computation---->comput
# analyze---->analyz
# analysis---->analysi
# analyst---->analyst
# analyzing---->analyz
# predict---->predict
# prediction---->predict
# predictive---->predict
# predicting---->predict

# %%
## stemming types

from nltk.stem import RegexpStemmer

stemmer = RegexpStemmer('ing$|ed$|s$', min=4)

words = ["eating", "eaten", "eats", "played", "plays", "running"]

[stemmer.stem(word) for word in words]
# Out:
# ['eat', 'eaten', 'eat', 'play', 'play', 'runn']

# %%
from nltk.stem import SnowballStemmer 

snowball = SnowballStemmer('english')

# %%
# [snowball.stem(words) for words in words1]
for words in words1:
    print(words+"---->"+ snowball.stem(words))
# Out:
# connect---->connect
# connected---->connect
# connecting---->connect
# connection---->connect
# connections---->connect
# compute---->comput
# computer---->comput
# computing---->comput
# computation---->comput
# analyze---->analyz
# analysis---->analysi
# analyst---->analyst
# analyzing---->analyz
# predict---->predict
# prediction---->predict
# predictive---->predict
# predicting---->predict

# %%
##Lemmatization
# ❗ Why not perfect?
# Because default POS = noun.

# 🔑 Correct way (WITH POS tags)

# You must tell WordNet what type of word it is.

# POS mapping
# POS	WordNet
# Noun	'n'
# Verb	'v'
# Adjective	'a'
# Adverb	'r'


from nltk.stem import WordNetLemmatizer

wordnet = WordNetLemmatizer()

# %%
words1 = [
    "connect", "connected", "connecting", "connection", "connections",
    "compute", "computer", "computing", "computation",
    "analyze", "analysis", "analyst", "analyzing",
    "predict", "prediction", "predictive", "predicting"
]

[wordnet.lemmatize(word,pos='v') for word in words1]
# Out:
# ['connect',
#  'connect',
#  'connect',
#  'connection',
#  'connections',
#  'compute',
#  'computer',
#  'compute',
#  'computation',
#  'analyze',
#  'analysis',
#  'analyst',
#  'analyze',
#  'predict',
#  'prediction',
#  'predictive',
#  'predict']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["eating", "eaten", "cars", "better", "running"]

[lemmatizer.lemmatize(word) for word in words]
# Out:
# ['eating', 'eaten', 'car', 'better', 'running']

# %%
# import nltk
# nltk.download('wordnet')
# nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# True

# %%
[lemmatizer.lemmatize(word,pos='v') for word in words]
# Out:
# ['eat', 'eat', 'cars', 'better', 'run']

# %%
words = ["cars", "wolves", "better", "running", "studies"]

lemmatized = [
    lemmatizer.lemmatize("cars", pos='n'),
    lemmatizer.lemmatize("wolves", pos='n'),
    lemmatizer.lemmatize("better", pos='a'),
    lemmatizer.lemmatize("running", pos='v'),
    lemmatizer.lemmatize("studies", pos='n')
]

lemmatized
# Out:
# ['car', 'wolf', 'good', 'run', 'study']

# %%
### Stop words 

paragraph = """
Success is not achieved overnight. It is the result of consistent effort, discipline, and the ability to learn from failure.
Many people want to achieve great things, but they are not willing to put in the hard work required.
If you believe in yourself and stay focused on your goals, you can overcome challenges and achieve success in life.
"""

# %%
##STOP WORDS

import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
sentences = sent_tokenize(paragraph)

# %%
stemmer = PorterStemmer()

for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['success achiev overnight .',
#  'it result consist effort , disciplin , abil learn failur .',
#  'mani peopl want achiev great thing , will put hard work requir .',
#  'if believ stay focus goal , overcom challeng achiev success life .']

# %%
from nltk.stem import SnowballStemmer

snow_stem = SnowballStemmer('english')

# %%
for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [snow_stem.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['success achiev overnight .',
#  'it result consist effort , disciplin , abil learn failur .',
#  'mani peopl want achiev great thing , will put hard work requir .',
#  'if believ stay focus goal , overcom challeng achiev success life .']

# %%
paragraph = """
Success is not achieved overnight. It is the result of consistent effort, discipline, and the ability to learn from failure.
Many people want to achieve great things, but they are not willing to put in the hard work required.
If you believe in yourself and stay focused on your goals, you can overcome challenges and achieve success in life.
"""

# %%
stop_words = set(stopwords.words('english'))

words = word_tokenize(paragraph.lower())

filtered_words = [word for word in words if word not in stop_words and word.isalpha()]

filtered_words
# Out:
# ['success',
#  'achieved',
#  'overnight',
#  'result',
#  'consistent',
#  'effort',
#  'discipline',
#  'ability',
#  'learn',
#  'failure',
#  'many',
#  'people',
#  'want',
#  'achieve',
#  'great',
#  'things',
#  'willing',
#  'put',
#  'hard',
#  'work',
#  'required',
#  'believe',
#  'stay',
#  'focused',
#  'goals',
#  'overcome',
#  'challenges',
#  'achieve',
#  'success',
#  'life']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word,pos='v') for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['Success achieve overnight .',
#  'It result consistent effort , discipline , ability learn failure .',
#  'Many people want achieve great things , will put hard work require .',
#  'If believe stay focus goals , overcome challenge achieve success life .']

# %%
##PARTS OF SPEECH TAGGING (POS)

# 🏷️ Common POS Tags (important ones)
# Tag	Meaning	Example
# NN	Noun	dog, city
# NNS	Plural noun	dogs
# VB	Verb (base)	run
# VBD	Verb (past)	ran
# VBG	Verb (gerund)	running
# JJ	Adjective	good
# RB	Adverb	quickly
# PRP	Pronoun	he, she
# DT	Determiner	the, a
# IN	Preposition	in, on

# %%
import nltk
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
paragraph = """
Success is not achieved overnight. It is the result of consistent effort, discipline, and the ability to learn from failure.
Many people want to achieve great things, but they are not willing to put in the hard work required.
If you believe in yourself and stay focused on your goals, you can overcome challenges and achieve success in life.
"""

# %%
sentences = sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words("english"))]
    pos_tag = nltk.pos_tag(words)
print(pos_tag)
# Out:
# [('If', 'IN'), ('believe', 'VBN'), ('stay', 'NN'), ('focused', 'JJ'), ('goals', 'NNS'), (',', ','), ('overcome', 'JJ'), ('challenges', 'NNS'), ('achieve', 'VBP'), ('success', 'NN'), ('life', 'NN'), ('.', '.')]

# %%
##NAMED ENTITY RECOGNITION 

import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
paragraph = """
On January 15, 2024, Sundar Pichai, the CEO of Google, announced a new AI initiative at the company's headquarters in Mountain View, California. 
The project, developed in collaboration with Microsoft and OpenAI, is expected to receive an investment of $2 billion over the next three years. 
During the event, Pichai mentioned that the new technology will be rolled out in India, the United States, and the United Kingdom by 2026.
"""

# %%
words = word_tokenize(paragraph)

# %%
pos_elements = nltk.pos_tag(words)
pos_elements
# Out:
# [('On', 'IN'),
#  ('January', 'NNP'),
#  ('15', 'CD'),
#  (',', ','),
#  ('2024', 'CD'),
#  (',', ','),
#  ('Sundar', 'NNP'),
#  ('Pichai', 'NNP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('CEO', 'NNP'),
#  ('of', 'IN'),
#  ('Google', 'NNP'),
#  (',', ','),
#  ('announced', 'VBD'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('AI', 'NNP'),
#  ('initiative', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ("'s", 'POS'),
#  ('headquarters', 'NN'),
#  ('in', 'IN'),
#  ('Mountain', 'NNP'),
#  ('View', 'NNP'),
#  (',', ','),
#  ('California', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('project', 'NN'),
#  (',', ','),
#  ('developed', 'VBN'),
#  ('in', 'IN'),
#  ('collaboration', 'NN'),
#  ('with', 'IN'),
#  ('Microsoft', 'NNP'),
#  ('and', 'CC'),
#  ('OpenAI', 'NNP'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('receive', 'VB'),
#  ('an', 'DT'),
#  ('investment', 'NN'),
#  ('of', 'IN'),
#  ('$', '$'),
#  ('2', 'CD'),
#  ('billion', 'CD'),
# ...

# %%
nltk.ne_chunk(pos_elements).draw()
