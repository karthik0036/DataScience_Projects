# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
img = cv2.imread("/content/puppy.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (827, 1240, 3)

# %%
grayScale_img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayScale_img)
# Out:
# numpy.ndarray

# %%
grayScale_img.shape
# Out:
# (827, 1240)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayScale_img)
# Out:
# <PIL.Image.Image image mode=L size=1240x827>
